# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Add intercept
X = sm.add_constant(X)

# Fit full regression model
full_model = sm.OLS(y, X).fit()

print(full_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     sc   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     39.10
# Date:                Tue, 25 Nov 2025   Prob (F-statistic):           9.47e-49
# Time:                        16:55:19   Log-Likelihood:                -236.48
# No. Observations:                 158   AIC:                             523.0
# Df Residuals:                     133   BIC:                             599.5
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -10.8779     32.958     -0.330      0.742     -76.068      54.312
# ...

# %%
# 5. Compute VIF for each predictor
vif_data = []
for i in range(X.shape[1]):
    vif = variance_inflation_factor(X.values, i)
    vif_data.append({"feature": X.columns[i], "VIF": vif})

vif_df = pd.DataFrame(vif_data)

# 6. View VIFs sorted from highest to lowest
vif_df = vif_df.sort_values("VIF", ascending=False).reset_index(drop=True)
print(vif_df)
# Out:
#                   feature            VIF
# 0                   const  123666.246668
# 1   classification_notckd      25.766684
# 2                      al      10.577934
# 3                 htn_yes       7.224765
# 4                     pcv       5.572952
# 5                    hemo       5.416711
# 6                  dm_yes       5.142438
# 7               pc_normal       4.377393
# 8                  pe_yes       3.913972
# 9                      sg       3.664204
# 10                    bgr       3.629898
# 11                     su       3.587412
# 12                ane_yes       3.516892
# 13                     bu       3.233411
# 14                     rc       2.986493
# 15             appet_poor       2.790668
# 16             rbc_normal       2.625764
# 17            pcc_present       2.369175
# 18                    sod       2.355220
# 19             ba_present       2.185774
# 20                     wc       2.001135
# 21                cad_yes       1.944257
# ...

# %%
# Get all p-values from the full model
pvals = full_model.pvalues
print(pvals.sort_values())
# Out:
# bu                       1.478447e-20
# pot                      7.056422e-04
# pe_yes                   7.211959e-03
# wc                       2.177285e-02
# al                       3.633665e-02
# ane_yes                  4.045354e-02
# pc_normal                4.467953e-02
# appet_poor               6.436540e-02
# bp                       6.626043e-02
# ba_present               8.480872e-02
# rc                       1.386924e-01
# pcv                      1.759531e-01
# rbc_normal               2.442753e-01
# su                       2.625403e-01
# hemo                     2.667429e-01
# pcc_present              3.434909e-01
# bgr                      4.433560e-01
# age                      6.639015e-01
# sg                       6.701571e-01
# htn_yes                  6.738584e-01
# const                    7.418799e-01
# cad_yes                  7.801163e-01
# sod                      9.787845e-01
# dm_yes                   9.923942e-01
# classification_notckd    9.998325e-01
# ...
